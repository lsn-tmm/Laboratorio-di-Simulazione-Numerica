# %% [markdown]
# # Metropolis

# %% [markdown]
# Prima della presa dati di ogni caso studiato il sistema viene lasciato equilibrare con $M_{eq} = 10^5$ steps. Ciascuna simulazione è poi realizzata con $M = 10^6$ steps totali e data blocking con $N = 100$ blocchi di $L = 10^4$ steps ciascuno.

# %% [markdown]
# ## Wave function: $\Psi_{100}$

# %% [markdown]
# $$
# \Psi_{1,0,0}(r,\theta,\phi)=
# \frac{a_0^{-3/2}}{\sqrt{\pi}} e^{-r/a_0}
# $$

# %% [markdown]
# ### Start from the origin $(0,0,0)$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(221)
ax1 = fig.add_subplot(222, projection='3d')
ax2 = fig.add_subplot(223)
ax3 = fig.add_subplot(224, projection='3d')

print('Psi_100')

x, f, error = np.loadtxt("Data/psi100_uni.0", usecols=(0,1,2), delimiter=' ', unpack='true')
ax.errorbar(x,f,yerr=error)
ax.plot((0,99),(1.5,1.5), c='r', label='$<r> = 3/2 a_0$')
ax.set_xlabel('# blocks')
ax.set_ylabel('<r>')
ax.set_title("Uniform transition probability")
ax.set_ylim(1.45,1.6)
ax.grid(True)
ax.legend()

X,Y,Z = np.loadtxt("Scatter/psi100_uni.0", usecols=(0,1,2), delimiter=' ', unpack='true')
ax1.scatter(X, Y, Z, c=Z, marker='.')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('z')
ax1.view_init(10, 30)

x, f, error = np.loadtxt("Data/psi100_multi.0", usecols=(0,1,2), delimiter=' ', unpack='true')
ax2.errorbar(x,f,yerr=error)
ax2.plot((0,99),(1.5,1.5), c='r', label='$<r> = 3/2 a_0$')
ax2.set_xlabel('# blocks')
ax2.set_ylabel('<r>')
ax2.set_title("Multivariate normal transition probability")
ax2.set_ylim(1.45,1.6)
ax2.grid(True)
ax2.legend()

X,Y,Z = np.loadtxt("Scatter/psi100_multi.0", usecols=(0,1,2), delimiter=' ', unpack='true')
ax3.scatter(X, Y, Z, c=Z, marker='.')
ax3.set_xlabel('x')
ax3.set_ylabel('y')
ax3.set_zlabel('z')
ax3.view_init(10, 30)

plt.tight_layout()
plt.show()
# Out:
# Psi_100

# %% [markdown]
# L'origine sembra essere un buon punto di partenza per l'algoritmo di Metropolis in quanto si trova già all'interno della distribuzione di probabilità che vogliamo campionare. Entrambe le transition probability $T(\vec{x}|\vec{y})$ convergono esattamente al valore atteso.

# %% [markdown]
# ### Start far from the origin $(10 a_0,10 a_0,10 a_0)$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(221)
ax1 = fig.add_subplot(222, projection='3d')
ax2 = fig.add_subplot(223)
ax3 = fig.add_subplot(224, projection='3d')

print('Psi_100')

x, f, error = np.loadtxt("Data/psi100_uni.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax.errorbar(x,f,yerr=error)
ax.plot((0,99),(1.5,1.5), c='r', label='$<r> = 3/2 a_0$')
ax.set_xlabel('# blocks')
ax.set_ylabel('<r>')
ax.set_title("Uniform transition probability")
ax.set_ylim(1.45,1.6)
ax.grid(True)
ax.legend()

X,Y,Z = np.loadtxt("Scatter/psi100_uni.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax1.scatter(X, Y, Z, c=Z, marker='.')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('z')
ax1.view_init(10, 30)

x, f, error = np.loadtxt("Data/psi100_multi.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax2.errorbar(x,f,yerr=error)
ax2.plot((0,99),(1.5,1.5), c='r', label='$<r> = 3/2 a_0$')
ax2.set_xlabel('# blocks')
ax2.set_ylabel('<r>')
ax2.set_title("Multivariate normal transition probability")
ax2.set_ylim(1.45,1.6)
ax2.grid(True)
ax2.legend()

X,Y,Z = np.loadtxt("Scatter/psi100_multi.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax3.scatter(X, Y, Z, c=Z, marker='.')
ax3.set_xlabel('x')
ax3.set_ylabel('y')
ax3.set_zlabel('z')
ax3.view_init(10, 30)

plt.tight_layout()
plt.show()
# Out:
# Psi_100

# %% [markdown]
# Anche una coordinata lontana dall'origine sembra essere un buon punto di partenza.
# Si può ben vedere dagli scatter-plot come nella fase di equilibrazione l'algoritmo di Metropolis riesca (in entrambi i casi) a direzionare le coordinate nei punti in cui la distribuzione di probabilità assume valori maggiori molto rapidamente.

# %% [markdown]
# ### Start very far from the origin $(100 a_0,100 a_0,100 a_0)$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(221)
ax1 = fig.add_subplot(222, projection='3d')
ax2 = fig.add_subplot(223)
ax3 = fig.add_subplot(224, projection='3d')

print('Psi_100')

x, f, error = np.loadtxt("Data/psi100_uni2.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax.errorbar(x,f,yerr=error)
ax.plot((0,99),(1.5,1.5), c='r', label='$<r> = 3/2 a_0$')
ax.set_xlabel('# blocks')
ax.set_ylabel('<r>')
ax.set_title("Uniform transition probability")
#ax.set_ylim(1.45,1.6)
ax.grid(True)
ax.legend()

X,Y,Z = np.loadtxt("Scatter/psi100_uni2.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax1.scatter(X, Y, Z, c=Z, marker='.')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('z')
ax1.view_init(10, 30)

x, f, error = np.loadtxt("Data/psi100_multi2.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax2.errorbar(x,f,yerr=error)
ax2.plot((0,99),(1.5,1.5), c='r', label='$<r> = 3/2 a_0$')
ax2.set_xlabel('# blocks')
ax2.set_ylabel('<r>')
ax2.set_title("Multivariate normal transition probability")
#ax2.set_ylim(1.45,1.6)
ax2.grid(True)
ax2.legend()

X,Y,Z = np.loadtxt("Scatter/psi100_multi2.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax3.scatter(X, Y, Z, c=Z, marker='.')
ax3.set_xlabel('x')
ax3.set_ylabel('y')
ax3.set_zlabel('z')
ax3.view_init(10, 30)

plt.tight_layout()
plt.show()
# Out:
# Psi_100

# %% [markdown]
# Anche in questo caso la coordinata iniziale sembra non essere un punto di partenza completamente errato, a patto di lasciare equilibrare il sistema un numero sufficiente di steps. Si può ben vedere infatti la convergenza sia molto più lenta rispetto al caso precendente, ma l'algoritmo di Metropolis riesce a individuare il percorso corretto per campionare la distribuzione di probabilità.

# %% [markdown]
# ## Wave function: $\Psi_{210}$

# %% [markdown]
# $$
# \Psi_{2,1,0}(r,\theta,\phi)=
# \frac{a_0^{-5/2}}{8}\sqrt{\frac{2}{\pi}} r e^{-r/2a_0} \cos(\theta)
# $$

# %% [markdown]
# ### Start close from the origin $(0.1a_0,0.1a_0,0.1a_0)$
# **NB**: l'origine in questo caso non è un buon punto di partenza in quanto la funzione d'onda non è definita in quel punto.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(221)
ax1 = fig.add_subplot(222, projection='3d')
ax2 = fig.add_subplot(223)
ax3 = fig.add_subplot(224, projection='3d')

print('Psi_210')

x, f, error = np.loadtxt("Data/psi210_uni.0", usecols=(0,1,2), delimiter=' ', unpack='true')
ax.errorbar(x,f,yerr=error)
ax.plot((0,99),(5,5), c='r', label='$<r> = 5 a_0$')
ax.set_xlabel('# blocks')
ax.set_ylabel('<r>')
ax.set_title("Uniform transition probability")
ax.set_ylim(4.8,5.25)
ax.grid(True)
ax.legend()

X,Y,Z = np.loadtxt("Scatter/psi210_uni.0", usecols=(0,1,2), delimiter=' ', unpack='true')
ax1.scatter(X, Y, Z, c=Z, marker='.')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('z')
ax1.view_init(10, 30)

x, f, error = np.loadtxt("Data/psi210_multi.0", usecols=(0,1,2), delimiter=' ', unpack='true')
ax2.errorbar(x,f,yerr=error)
ax2.plot((0,99),(5,5), c='r', label='$<r> = 5 a_0$')
ax2.set_xlabel('# blocks')
ax2.set_ylabel('<r>')
ax2.set_title("Multivariate normal transition probability")
ax2.set_ylim(4.8,5.25)
ax2.grid(True)
ax2.legend()

X,Y,Z = np.loadtxt("Scatter/psi210_multi.0", usecols=(0,1,2), delimiter=' ', unpack='true')
ax3.scatter(X, Y, Z, c=Z, marker='.')
ax3.set_xlabel('x')
ax3.set_ylabel('y')
ax3.set_zlabel('z')
ax3.view_init(10, 30)

plt.tight_layout()
plt.show()
# Out:
# Psi_210

# %% [markdown]
# Anche in questo caso una coordinata vicina all'origine sembra essere un buon punto di partenza per l'algoritmo. L'algoritmo riesce a campionare correttamente la distribuzione di probablità.

# %% [markdown]
# ### Start far from the origin $(10 a_0,10 a_0,10 a_0)$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(221)
ax1 = fig.add_subplot(222, projection='3d')
ax2 = fig.add_subplot(223)
ax3 = fig.add_subplot(224, projection='3d')

print('Psi_210')

x, f, error = np.loadtxt("Data/psi210_uni.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax.errorbar(x,f,yerr=error)
ax.plot((0,99),(5,5), c='r', label='$<r> = 5 a_0$')
ax.set_xlabel('# blocks')
ax.set_ylabel('<r>')
ax.set_title("Uniform transition probability")
ax.set_ylim(4.8,5.25)
ax.grid(True)
ax.legend()

X,Y,Z = np.loadtxt("Scatter/psi210_uni.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax1.scatter(X, Y, Z, c=Z, marker='.')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('z')
ax1.view_init(10, 30)

x, f, error = np.loadtxt("Data/psi210_multi.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax2.errorbar(x,f,yerr=error)
ax2.plot((0,99),(5,5), c='r', label='$<r> = 5 a_0$')
ax2.set_xlabel('# blocks')
ax2.set_ylabel('<r>')
ax2.set_title("Multivariate normal transition probability")
ax2.set_ylim(4.8,5.25)
ax2.grid(True)
ax2.legend()

X,Y,Z = np.loadtxt("Scatter/psi210_multi.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax3.scatter(X, Y, Z, c=Z, marker='.')
ax3.set_xlabel('x')
ax3.set_ylabel('y')
ax3.set_zlabel('z')
ax3.view_init(10, 30)

plt.tight_layout()
plt.show()
# Out:
# Psi_210

# %% [markdown]
# La coordinata fornita è un buon punto di partenza come nel caso precedente.

# %% [markdown]
# ### Start very far from the origin $(100 a_0,100 a_0,100 a_0)$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(221)
ax1 = fig.add_subplot(222, projection='3d')
ax2 = fig.add_subplot(223)
ax3 = fig.add_subplot(224, projection='3d')

print('Psi_210')

x, f, error = np.loadtxt("Data/psi210_uni2.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax.errorbar(x,f,yerr=error)
ax.plot((0,99),(5.,5.), c='r', label='$<r> = 5 a_0$')
ax.set_xlabel('# blocks')
ax.set_ylabel('<r>')
ax.set_title("Uniform transition probability")
#ax.set_ylim(4.8,5.25)
ax.grid(True)
ax.legend()

X,Y,Z = np.loadtxt("Scatter/psi210_uni2.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax1.scatter(X, Y, Z, c=Z, marker='.')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('z')
ax1.view_init(10, 30)

x, f, error = np.loadtxt("Data/psi210_multi2.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax2.errorbar(x,f,yerr=error)
ax2.plot((0,99),(5.,5.), c='r', label='$<r> = 5 a_0$')
ax2.set_xlabel('# blocks')
ax2.set_ylabel('<r>')
ax2.set_title("Multivariate normal transition probability")
#x2.set_ylim(4.8,5.25)
ax2.grid(True)
ax2.legend()

X,Y,Z = np.loadtxt("Scatter/psi210_multi2.pos", usecols=(0,1,2), delimiter=' ', unpack='true')
ax3.scatter(X, Y, Z, c=Z, marker='.')
ax3.set_xlabel('x')
ax3.set_ylabel('y')
ax3.set_zlabel('z')
ax3.view_init(10, 30)

plt.tight_layout()
plt.show()
# Out:
# Psi_210

# %% [markdown]
# Possono essere fatte analoghe considerazioni alla funzione d'onda precedente. Lasciando equilibrare il sistema l'algoritmo di Metropolis riesce a individuare il percorso corretto per campionare la distribuzione di probabilità.
